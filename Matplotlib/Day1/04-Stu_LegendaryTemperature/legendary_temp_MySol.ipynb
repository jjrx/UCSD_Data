# %%
# Include this line to make plots interactive
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
months = np.arange(1, 13)
fahr_temps = [39, 42, 51, 62, 72, 82, 86, 84, 77, 65, 55, 44]
celsius_temps = [(F - 32) * 0.56 for F in fahr_temps]

# %%
fahr, = plt.plot(months, fahr_temps, marker='+', color='blue')
cels, = plt.plot(months, celsius_temps, marker='s', color='red')
plt.xlabel('Month')
plt.ylabel('Temperature')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Temperature')

# %%
plt.legend(handles=[fahr, cels], loc="best")
# Out:
# /Users/Jasmin/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x116dc50f0> has a label of '_line0' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /Users/Jasmin/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x10b85ff60> has a label of '_line1' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
