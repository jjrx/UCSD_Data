# %%
# Include this line to make plots interactive
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
months = np.arange(1, 13)
fahr_temps = [39, 42, 51, 62, 72, 82, 86, 84, 77, 65, 55, 44]
celsius_temps = [(F - 32) * 0.56 for F in fahr_temps]

# %%
plt.plot(months, fahr_temps, marker='+', color='blue')
plt.plot(months, celsius_temps, marker='s', color='red')
plt.xlabel('Month')
plt.ylabel('Temperature')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Temperature')

# %%
plt.legend(handles=[fahr_temps, celsius_temps], loc="best")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-bb6bec506266> in <module>()
# ----> 1 plt.legend(handles=[fahr_temps, celsius_temps], loc="best")
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    3816 @docstring.copy_dedent(Axes.legend)
#    3817 def legend(*args, **kwargs):
# -> 3818     ret = gca().legend(*args, **kwargs)
#    3819     return ret
#    3820
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     552                 [self],
#     553                 *args,
# --> 554                 **kwargs)
#     555         if len(extra_args):
#     556             raise TypeError('legend only accepts two non-keyword arguments')
#
# ...

# %%
plt.
